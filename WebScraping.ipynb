# %% [markdown]
# # WebScraping :

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import math

# %%
import requests

r = requests.get('http://www.popvortex.com/music/charts/top-100-songs.php')
r.status_code
# Out:
# 200

# %%
html = response.content

# %%
soup = BeautifulSoup(response.content, 'html.parser')  #creating a soup to

# %%
artists = soup.select("artist_list")

# %%
type(soup)
# all the website is stored into soup
# Out:
# bs4.BeautifulSoup

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.title
# Out:
# <title>iTunes Top 100 Songs Chart 2022</title>

# %%
r.headers
# Out:
# {'Date': 'Fri, 03 Jun 2022 09:25:40 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-Powered-By': 'PHP/7.3.11', 'X-UA-Compatible': 'IE=edge', 'Vary': 'Accept-Encoding,User-Agent', 'CF-Cache-Status': 'DYNAMIC', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=6q78ttyFmVCtUQD3O8SqkK8Ag5ktoHnlYW61zrvBqEh5AI%2ByjpqFtrsGPM%2Frs04%2FzyMy5fDvoAxMtW56KjMkU0pv%2Fx7rKLSb56FCVUjaCp0Zh9ZtEU7uN8MyPVknJPM5csCmvw%3D%3D"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"success_fraction":0,"report_to":"cf-nel","max_age":604800}', 'Server': 'cloudflare', 'CF-RAY': '715761fdcdcc0132-AMS', 'Content-Encoding': 'gzip', 'alt-svc': 'h3=":443"; ma=86400, h3-29=":443"; ma=86400'}

# %%
html_doc = r.content
html
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><title>iTunes Top 100 Songs Chart 2022</title><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="description" content="iTunes top 100 songs chart list. The most popular hit music and trending songs of 2022. Chart of today\'s current iTunes top 100 songs is updated daily."><meta property="og:title" content="iTunes Top 100 Songs Chart 2022"/><meta property="og:description" content="Chart of the top 100 songs on iTunes. Chart list of the top 100 song downloads of 2022 is updated daily."/><meta property="og:type" content="article"/><meta property="og:image" content="http://www.popvortex.com/images/logo-facebook.png"/><meta property="og:site_name" content="PopVortex"/><meta property="og:url" content="http://www.popvortex.com/music/charts/top-100-songs.php"/><meta property="fb:admins" content="100000239962942"/><meta property="fb:app_id" content="178831188827052"/><link rel="shortcut icon" href="/favi
# ...

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# get all elements of a tag
soup.find_all("p", attrs={'class': 'story'})
# Out:
# []

# %%
soup.find_all("a")#[0].get("href")
# Out:
# [<a class="navbar-brand" href="/"><img alt="PopVortex - Music, Books, Movies, Televsion" height="80" src="/images/popvortex-logo.png" style="border-width: 0px" width="126"/></a>,
#  <a class="dropdown-toggle" data-toggle="dropdown" href="/music/">Music <b class="caret"></b></a>,
#  <a href="/music/">Music News and Reviews</a>,
#  <a href="/music/charts/">iTunes Music Charts</a>,
#  <a href="/music/charts/"><strong>iTunes Top Song Charts</strong></a>,
#  <a href="/music/charts/top-100-songs.php">iTunes Top 100 Songs</a>,
#  <a href="/music/charts/apple-music-top-songs.php">Apple Top 200 Streams</a>,
#  <a href="/music/charts/top-country-songs.php">Top Country Songs</a>,
#  <a href="/music/charts/top-pop-songs.php">Top Pop Songs</a>,
#  <a href="/music/charts/top-rap-songs.php">Top Rap Songs</a>,
#  <a href="/music/charts/top-alternative-songs.php">Top Alternative Songs</a>,
#  <a href="/music/charts/"><strong>iTunes Top Album Charts</strong></a>,
# ...

# %%
html_table = soup.find_all

# %%
html_table
# Out:
# <bound method Tag.find_all of <!DOCTYPE html>
# ...

# %%
import pandas as pd

df = pd.read_html(html_table.prettify())[0]
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_57276/2840710501.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_html(html_table.prettify())[0]
#       4 df
#
# AttributeError: 'function' object has no attribute 'prettify'

# %%
r.cookies
# Out:
# <RequestsCookieJar[]>

# %%
for link in soup.find_all('a'):
    print(link.get('href')) # get_text(strip=True)
# Out:
# /
# /music/
# /music/
# /music/charts/
# /music/charts/
# /music/charts/top-100-songs.php
# /music/charts/apple-music-top-songs.php
# /music/charts/top-country-songs.php
# /music/charts/top-pop-songs.php
# /music/charts/top-rap-songs.php
# /music/charts/top-alternative-songs.php
# /music/charts/
# /music/charts/top-100-albums.php
# /music/charts/top-country-albums.php
# /music/charts/top-pop-albums.php
# /music/charts/top-rap-albums.php
# /music/charts/top-alternative-albums.php
# /charts/international-charts.php
# /books/
# /books/
# /books/charts/audiobooks.php
# /books/charts/top-audio-books.php
# /books/charts/fiction-audiobooks.php
# /books/charts/non-fiction-audiobooks.php
# /books/charts/new-audiobooks.php
# /books/charts/ebooks.php
# /books/charts/top-ebooks.php
# /books/charts/top-fiction-ebooks.php
# /books/charts/top-non-fiction-ebooks.php
# /movies/
# /movies/
# /movies/charts/top-movies.php
# /tv/
# /tv/
# /tv/charts/top-tv-episodes.php
# /tv/charts/top-tv-seasons.php
# ...

# %%
# exactly the same results as before:
for link in soup.find_all('a'):
    print(link['href'])
# Out:
# /
# /music/
# /music/
# /music/charts/
# /music/charts/
# /music/charts/top-100-songs.php
# /music/charts/apple-music-top-songs.php
# /music/charts/top-country-songs.php
# /music/charts/top-pop-songs.php
# /music/charts/top-rap-songs.php
# /music/charts/top-alternative-songs.php
# /music/charts/
# /music/charts/top-100-albums.php
# /music/charts/top-country-albums.php
# /music/charts/top-pop-albums.php
# /music/charts/top-rap-albums.php
# /music/charts/top-alternative-albums.php
# /charts/international-charts.php
# /books/
# /books/
# /books/charts/audiobooks.php
# /books/charts/top-audio-books.php
# /books/charts/fiction-audiobooks.php
# /books/charts/non-fiction-audiobooks.php
# /books/charts/new-audiobooks.php
# /books/charts/ebooks.php
# /books/charts/top-ebooks.php
# /books/charts/top-fiction-ebooks.php
# /books/charts/top-non-fiction-ebooks.php
# /movies/
# /movies/
# /movies/charts/top-movies.php
# /tv/
# /tv/
# /tv/charts/top-tv-episodes.php
# /tv/charts/top-tv-seasons.php
# ...

# %%
# extract content
soup.get_text(strip=True, separator=' ')
# Out:
# 'iTunes Top 100 Songs Chart 2022 Toggle navigation Music Music News and Reviews iTunes Music Charts iTunes Top Song Charts iTunes Top 100 Songs Apple Top 200 Streams Top Country Songs Top Pop Songs Top Rap Songs Top Alternative Songs iTunes Top Album Charts iTunes Top 100 Albums Top Country Albums Top Pop Albums Top Rap Albums Top Alternative Albums International iTunes Charts Books Book News and Reviews Audiobook Charts by Genre Audiobook Bestsellers Fiction Audiobook Best Sellers Non-Fiction Audiobook Best Sellers Top New Audiobooks Ebook Best Seller Charts by Genre Ebook Best Sellers Fiction Ebook Best Sellers Non-Fiction Ebook Best Sellers Movies Movie News, Revies & Box Office Reports Top iTunes Movies Television TV News Top TV Episodes Top TV Seasons Apps Top Paid iPhone Apps Top Free iPhone Apps Top Paid iPad Apps Top Free iPad Apps Top Mac Apps Top Free Mac Apps World Charts Home Music Music Charts iTunes Top 100 Songs iTunes Top 100 Songs Chart Chart of iTunes top 100 songs 
# ...

# %% [markdown]
# # first getting the number of total results

# %%
table=soup.find('div',{'id':'TableWithRules'})

# %%
# parse the element
soup = BeautifulSoup(html_doc, 'html.parser')
soup
# html well indented. not always works great...
print(soup.prettify()) ### try without prettify
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    iTunes Top 100 Songs Chart 2022
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="iTunes top 100 songs chart list. The most popular hit music and trending songs of 2022. Chart of today's current iTunes top 100 songs is updated daily." name="description"/>
#   <meta content="iTunes Top 100 Songs Chart 2022" property="og:title">
#    <meta content="Chart of the top 100 songs on iTunes. Chart list of the top 100 song downloads of 2022 is updated daily." property="og:description">
#     <meta content="article" property="og:type">
#      <meta content="http://www.popvortex.com/images/logo-facebook.png" property="og:image"/>
#      <meta content="PopVortex" property="og:site_name"/>
#      <meta content="http://www.popvortex.com/music/charts/top-100-songs.php" property="og:url"/>
#      <meta content="100000239962942" property="fb:admins"/>
# ...

# %%
# basic tree navigation
soup.title.get_text(strip=True)  ### try soup.title.text
# Out:
# 'iTunes Top 100 Songs Chart 2022'

# %%
tables = pd.read_html(url)
print(tables[1][1])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_57276/16656694.py in <module>
# ----> 1 tables = pd.read_html(url)
#       2 print(tables[1][1])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
#    1100         io=io,
#
# ...

# %% [markdown]
# # Listing song and artists names

# %%
name_song = []

# %% [markdown]
# Listing artists

# %%
artist_list = []

for artist in artists:
    artist_list.append(artist.text)

artist_list
# Out:
# []

# %%
def get_playlist_songs(self, playlist_id, limit=1000):
     """Get a playlists's all songs.
      :params playlist_id: playlist id.
        :params limit: length of result returned by weapi.
        :return: a list of Song object.
        """

# %%
url = 'http://www.popvortex.com/music/charts/top-100-songs.php'
csrf = ''
params = {'id': playlist_id, 'offset': 0, 'total': True,
                  'limit': limit, 'n': 1000, 'csrf_token': csrf}
result = self.post_request(url, params)

songs = result['playlist']['tracks']
songs = [Song(song['id'], song['name']) for song in songs]
return songs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_57276/1711551712.py in <module>
#       1 url = 'http://www.popvortex.com/music/charts/top-100-songs.php'
#       2 csrf = ''
# ----> 3 params = {'id': playlist_id, 'offset': 0, 'total': True,
#       4                   'limit': limit, 'n': 1000, 'csrf_token': csrf}
#       5 result = self.post_request(url, params)
#
# NameError: name 'playlist_id' is not defined

# %%
music = ('charts')

# %%
music = ('charts'['id'],charts['name'])
# Out:
# <>:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# <>:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# C:\Users\samag\AppData\Local\Temp/ipykernel_57276/759794619.py:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
#   music = ('charts'['id'],charts['name'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_57276/759794619.py in <module>
# ----> 1 music = ('charts'['id'],charts['name'])
#
# TypeError: string indices must be integers

# %%
music=[songs]

# %%
def getSongs(self):
        self.songs = []
        try:
            pn = 1
            api = self.infoApi % (self.sid, "%s")
            while True:
                url = api % pn
                data = requests.get(url, self.headers).json()
                for song in data["data"]["data"]:
                    temp = songDownloader(str(song["id"]))
                    temp.title = song["title"]
                    temp.author = song["author"]
                    temp.lyric = song["lyric"]
                    temp.cover = song["cover"]
                    self.songs.append(temp)

                if data["data"]["pageCount"] == data["data"]["curPage"]:
                    break
                pn += 1
        except:
            pass
